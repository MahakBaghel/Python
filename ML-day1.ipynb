# %%
#import all library
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LinearRegression

# %%
hours = np.array([1,2,3,4,5,6])
score = np.array([33,38,43,56,76,88])

# %%
sns.regplot(x = hours,y = score)
plt.grid()
plt.show()

# %%
#data collect
df = pd.read_csv('/content/Student_Marks.csv')
# data preprocessing
print(df.info())
#fillna or dropna
# features selection
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 3 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   number_courses  100 non-null    int64
#  1   time_study      100 non-null    float64
#  2   Marks           100 non-null    float64
# dtypes: float64(2), int64(1)
# memory usage: 2.5 KB
# None

# %%
#data insights
'''
0   number_courses  100 non-null    int64
 1   time_study      100 non-null    float64
 2   Marks           100 non-null    float64
'''
# Out:
# '\n0   number_courses  100 non-null    int64  \n 1   time_study      100 non-null    float64\n 2   Marks           100 non-null    float64\n'

# %%
corr = df.corr(numeric_only = True)
sns.heatmap(corr)
# Out:
# <Axes: >

# %%
# take out marks and number of cources from dataframe
marks = df["Marks"]
time_study = df['time_study']
noc = df["number_courses"]

# %%
noc = noc.sort_values()

# %%
plt.plot(noc,marks)

# %%
plt.plot(time_study,marks)

# %%
plt.bar(time_study,marks)
# Out:
# <BarContainer object of 100 artists>

# %%
#outliers detection
plt.boxplot(df['time_study'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7eef941e0440>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7eef941e09e0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7eef9555a6f0>],
#  'medians': [<matplotlib.lines.Line2D at 0x7eef941e0fb0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7eef941e1280>],
#  'means': []}

# %%
plt.boxplot(df['Marks'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7eef94244b60>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7eef942450d0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7eef943121b0>],
#  'medians': [<matplotlib.lines.Line2D at 0x7eef942456a0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7eef94245940>],
#  'means': []}

# %%
plt.boxplot(df['number_courses'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7eef942e4b30>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7eef942e6120>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7eef94312bd0>],
#  'medians': [<matplotlib.lines.Line2D at 0x7eef942e4b60>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7eef95945730>],
#  'means': []}
