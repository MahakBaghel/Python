# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('/content/Housing.csv')
print(df)
# Out:
#           price  area  bedrooms  bathrooms  stories mainroad guestroom  \
# 0    13300000.0  7420       4.0        2.0      3.0      yes        no
# 1    12250000.0  8960       4.0        4.0      4.0      yes        no
# 2    12250000.0  9960       3.0        2.0      2.0      yes        no
# 3    12215000.0  7500       4.0        2.0      2.0      yes        no
# 4    11410000.0  7420       4.0        1.0      2.0      yes       yes
# ..          ...   ...       ...        ...      ...      ...       ...
# 540   1820000.0  3000       2.0        1.0      1.0      yes        no
# 541   1767150.0  2400       3.0        1.0      1.0       no        no
# 542   1750000.0  3620       2.0        1.0      1.0      yes        no
# 543   1750000.0  2910       3.0        1.0      1.0       no        no
# 544   1750000.0  3850       3.0        1.0      2.0      yes        no
#
#     basement hotwaterheating airconditioning  parking prefarea  \
# ...

# %%
#selecting\accessing column
df[["price","area","bedrooms","bathrooms","basement"]]
# Out:
#           price  area  bedrooms  bathrooms basement
# 0    13300000.0  7420       4.0        2.0       no
# 1    12250000.0  8960       4.0        4.0       no
# 2    12250000.0  9960       3.0        2.0      yes
# 3    12215000.0  7500       4.0        2.0      yes
# 4    11410000.0  7420       4.0        1.0      yes
# ..          ...   ...       ...        ...      ...
# 540   1820000.0  3000       2.0        1.0      yes
# 541   1767150.0  2400       3.0        1.0       no
# 542   1750000.0  3620       2.0        1.0       no
# 543   1750000.0  2910       3.0        1.0       no
# 544   1750000.0  3850       3.0        1.0       no
#
# [545 rows x 5 columns]

# %%
df['area'].mean()
#df['area'].sum()
#df['area'].mim()
#df['area'].max()
df['area'].std()
# Out:
# 2170.141022508803

# %%
#select data row wise
df.loc[4]
# Out:
# price               11410000.0
# area                      7420
# bedrooms                   4.0
# bathrooms                  1.0
# stories                    2.0
# mainroad                   yes
# guestroom                  yes
# basement                   yes
# hotwaterheating             no
# airconditioning            yes
# parking                      2
# prefarea                    no
# furnishingstatus     furnished
# Name: 4, dtype: object

# %%
#select data index wise
df.iloc[5]
# Out:
# price                   10850000.0
# area                          7500
# bedrooms                       3.0
# bathrooms                      3.0
# stories                        1.0
# mainroad                       yes
# guestroom                       no
# basement                       yes
# hotwaterheating                 no
# airconditioning                yes
# parking                          2
# prefarea                       yes
# furnishingstatus    semi-furnished
# Name: 5, dtype: object

# %%
#filtering data
df[df["price"]<11410000.0]
# Out:
#           price   area  bedrooms  bathrooms  stories mainroad guestroom  \
# 5    10850000.0   7500       3.0        3.0      1.0      yes        no
# 6    10150000.0   8580       4.0        3.0      4.0      yes        no
# 7    10150000.0  16200       5.0        3.0      2.0      yes        no
# 8     9870000.0   8100       4.0        1.0      2.0      yes       yes
# 9     9800000.0   5750       3.0        2.0      4.0      yes       yes
# ..          ...    ...       ...        ...      ...      ...       ...
# 540   1820000.0   3000       2.0        1.0      1.0      yes        no
# 541   1767150.0   2400       3.0        1.0      1.0       no        no
# 542   1750000.0   3620       2.0        1.0      1.0      yes        no
# 543   1750000.0   2910       3.0        1.0      1.0       no        no
# 544   1750000.0   3850       3.0        1.0      2.0      yes        no
#
#     basement hotwaterheating airconditioning  parking prefarea  \
# ...

# %%
#adding column
df["Price_in_Lakhs"] = df["price"] / 100000
print(df)
# Out:
#           price  area  bedrooms  bathrooms  stories mainroad guestroom  \
# 0    13300000.0  7420       4.0        2.0      3.0      yes        no
# 1    12250000.0  8960       4.0        4.0      4.0      yes        no
# 2    12250000.0  9960       3.0        2.0      2.0      yes        no
# 3    12215000.0  7500       4.0        2.0      2.0      yes        no
# 4    11410000.0  7420       4.0        1.0      2.0      yes       yes
# ..          ...   ...       ...        ...      ...      ...       ...
# 540   1820000.0  3000       2.0        1.0      1.0      yes        no
# 541   1767150.0  2400       3.0        1.0      1.0       no        no
# 542   1750000.0  3620       2.0        1.0      1.0      yes        no
# 543   1750000.0  2910       3.0        1.0      1.0       no        no
# 544   1750000.0  3850       3.0        1.0      2.0      yes        no
#
#     basement hotwaterheating airconditioning  parking prefarea  \
# ...

# %%
print(df.columns)
# Out:
# Index(['price', 'area', 'bedrooms', 'bathrooms', 'stories', 'mainroad',
#        'guestroom', 'basement', 'hotwaterheating', 'airconditioning',
#        'parking', 'prefarea', 'furnishingstatus'],
#       dtype='object')

# %%
#removing column
#axis =1 used for column,inplace is used for delete permanently
df.drop('area',axis=1,inplace=True,errors="ignore")
print(df)
# Out:
#           price  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0    13300000.0       4.0        2.0      3.0      yes        no       no
# 1    12250000.0       4.0        4.0      4.0      yes        no       no
# 2    12250000.0       3.0        2.0      2.0      yes        no      yes
# 3    12215000.0       4.0        2.0      2.0      yes        no      yes
# 4    11410000.0       4.0        1.0      2.0      yes       yes      yes
# ..          ...       ...        ...      ...      ...       ...      ...
# 540   1820000.0       2.0        1.0      1.0      yes        no      yes
# 541   1767150.0       3.0        1.0      1.0       no        no       no
# 542   1750000.0       2.0        1.0      1.0      yes        no       no
# 543   1750000.0       3.0        1.0      1.0       no        no       no
# 544   1750000.0       3.0        1.0      2.0      yes        no       no
#
#     hotwaterheating airconditioning  parking prefarea furnishingstatus
# ...

# %%
# give null values of all columns
df.isnull().sum()
# Out:
# price               3
# bedrooms            2
# bathrooms           2
# stories             1
# mainroad            0
# guestroom           0
# basement            0
# hotwaterheating     0
# airconditioning     0
# parking             0
# prefarea            0
# furnishingstatus    0
# dtype: int64

# %%
#fill the null values with zero
df.fillna(0)
# Out:
#           price  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0    13300000.0       4.0        2.0      3.0      yes        no       no
# 1    12250000.0       4.0        4.0      4.0      yes        no       no
# 2    12250000.0       3.0        2.0      2.0      yes        no      yes
# 3    12215000.0       4.0        2.0      2.0      yes        no      yes
# 4    11410000.0       4.0        1.0      2.0      yes       yes      yes
# ..          ...       ...        ...      ...      ...       ...      ...
# 540   1820000.0       2.0        1.0      1.0      yes        no      yes
# 541   1767150.0       3.0        1.0      1.0       no        no       no
# 542   1750000.0       2.0        1.0      1.0      yes        no       no
# 543   1750000.0       3.0        1.0      1.0       no        no       no
# 544   1750000.0       3.0        1.0      2.0      yes        no       no
#
#     hotwaterheating airconditioning  parking prefarea furnishingstatus
# ...

# %%
#remove all NaN values from dataset
df.dropna()
# Out:
#           price  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0    13300000.0       4.0        2.0      3.0      yes        no       no
# 1    12250000.0       4.0        4.0      4.0      yes        no       no
# 2    12250000.0       3.0        2.0      2.0      yes        no      yes
# 3    12215000.0       4.0        2.0      2.0      yes        no      yes
# 4    11410000.0       4.0        1.0      2.0      yes       yes      yes
# ..          ...       ...        ...      ...      ...       ...      ...
# 540   1820000.0       2.0        1.0      1.0      yes        no      yes
# 541   1767150.0       3.0        1.0      1.0       no        no       no
# 542   1750000.0       2.0        1.0      1.0      yes        no       no
# 543   1750000.0       3.0        1.0      1.0       no        no       no
# 544   1750000.0       3.0        1.0      2.0      yes        no       no
#
#     hotwaterheating airconditioning  parking prefarea furnishingstatus
# ...

# %%
df.sort_values('price')
# Out:
#           price  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 544   1750000.0       3.0        1.0      2.0      yes        no       no
# 543   1750000.0       3.0        1.0      1.0       no        no       no
# 542   1750000.0       2.0        1.0      1.0      yes        no       no
# 541   1767150.0       3.0        1.0      1.0       no        no       no
# 540   1820000.0       2.0        1.0      1.0      yes        no      yes
# ..          ...       ...        ...      ...      ...       ...      ...
# 2    12250000.0       3.0        2.0      2.0      yes        no      yes
# 0    13300000.0       4.0        2.0      3.0      yes        no       no
# 76          NaN       3.0        2.0      3.0      yes        no       no
# 90          NaN       3.0        1.0      2.0      yes        no       no
# 122         NaN       4.0        2.0      1.0      yes        no      yes
#
#     hotwaterheating airconditioning  parking prefarea furnishingstatus
# ...

# %%
df.sort_index()
# Out:
#           price  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0    13300000.0       4.0        2.0      3.0      yes        no       no
# 1    12250000.0       4.0        4.0      4.0      yes        no       no
# 2    12250000.0       3.0        2.0      2.0      yes        no      yes
# 3    12215000.0       4.0        2.0      2.0      yes        no      yes
# 4    11410000.0       4.0        1.0      2.0      yes       yes      yes
# ..          ...       ...        ...      ...      ...       ...      ...
# 540   1820000.0       2.0        1.0      1.0      yes        no      yes
# 541   1767150.0       3.0        1.0      1.0       no        no       no
# 542   1750000.0       2.0        1.0      1.0      yes        no       no
# 543   1750000.0       3.0        1.0      1.0       no        no       no
# 544   1750000.0       3.0        1.0      2.0      yes        no       no
#
#     hotwaterheating airconditioning  parking prefarea furnishingstatus
# ...

# %%
df.head(2)
# Out:
#         price  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0  13300000.0       4.0        2.0      3.0      yes        no       no
# 1  12250000.0       4.0        4.0      4.0      yes        no       no
#
#   hotwaterheating airconditioning  parking prefarea furnishingstatus
# 0              no             yes        2      yes        furnished
# 1              no             yes        3       no        furnished

# %%
df.tail(2)
# Out:
#          price  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 543  1750000.0       3.0        1.0      1.0       no        no       no
# 544  1750000.0       3.0        1.0      2.0      yes        no       no
#
#     hotwaterheating airconditioning  parking prefarea furnishingstatus
# 543              no              no        0       no        furnished
# 544              no              no        0       no      unfurnished

# %%
pivot_table = df.pivot_table(
    index="furnishingstatus",
    columns="bedrooms",
    values="price",
    aggfunc="mean"
)

print(pivot_table)
# Out:
# bedrooms                1.0           2.0           3.0           4.0  \
# furnishingstatus
# furnished         3150000.0  4.114250e+06  5.443286e+06  6.953655e+06
# semi-furnished          NaN  3.984260e+06  5.038964e+06  5.534989e+06
# unfurnished       2275000.0  3.070667e+06  4.443015e+06  4.254250e+06
#
# bedrooms                5.0        6.0
# furnishingstatus
# furnished         5974500.0  6083000.0
# semi-furnished    4095000.0        NaN
# unfurnished       6527500.0  3500000.0
